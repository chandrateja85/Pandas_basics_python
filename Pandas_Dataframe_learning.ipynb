# %% [markdown]
# <a href="https://colab.research.google.com/github/chandrateja85/Pandas_basics_python/blob/main/Pandas_Dataframe_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
cols=['a','b','c','d','e']
rows=['x','y','z']
data=np.round(np.random.randn(3,5),2)
df=pd.DataFrame(data,rows,cols)
print(df)
# Out:
#       a     b     c     d     e
# x  1.92 -1.44  0.34 -0.85  0.07
# y  1.43  0.29  0.77 -1.81  0.29
# z -0.68 -0.28 -0.12 -0.82  0.29

# %% [markdown]
# **ACCESSING** **COLOUMNS**

# %%
df['a']
# Out:
# x    1.92
# y    1.43
# z   -0.68
# Name: a, dtype: float64

# %%
df['b']
# Out:
# x   -1.44
# y    0.29
# z   -0.28
# Name: b, dtype: float64

# %%
df['c']
# Out:
# x    0.34
# y    0.77
# z   -0.12
# Name: c, dtype: float64

# %%
df[[a,b]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-5991351a8bf3> in <cell line: 1>()
# ----> 1 df[[a,b]]
#
# NameError: name 'a' is not defined

# %%
df['a','b']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('a', 'b')
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df[['a','b']]
# Out:
#       a     b
# x  1.92 -1.44
# y  1.43  0.29
# z -0.68 -0.28

# %%
df[['a','c']]
# Out:
#       a     c
# x  1.92  0.34
# y  1.43  0.77
# z -0.68 -0.12

# %% [markdown]
# **ACCESSING** **ROWS**

# %%
#df.loc['coloumn name']
df.loc['x']
# Out:
# a    1.92
# b   -1.44
# c    0.34
# d   -0.85
# e    0.07
# Name: x, dtype: float64

# %%
df.loc['y']
# Out:
# a    1.43
# b    0.29
# c    0.77
# d   -1.81
# e    0.29
# Name: y, dtype: float64

# %%
df.loc[['x','y']]
# Out:
#       a     b     c     d     e
# x  1.92 -1.44  0.34 -0.85  0.07
# y  1.43  0.29  0.77 -1.81  0.29

# %% [markdown]
#   **ACCESSING THE PARTICULAR VALUES**

# %%
df['a']['y']
# Out:
# 1.43

# %%
df['b']['z']
# Out:
# -0.28

# %%
df
# Out:
#       a     b     c     d     e
# x  1.92 -1.44  0.34 -0.85  0.07
# y  1.43  0.29  0.77 -1.81  0.29
# z -0.68 -0.28 -0.12 -0.82  0.29

# %%
df['a+b']=df['a']+df['b']

# %%
df['c']
# Out:
# x    0.34
# y    0.77
# z   -0.12
# Name: c, dtype: float64

# %%
df['c']>0 # It prints the boolean values of a coloumn based on the condition if that value is greater than 0 then it returns 1else it returns 0
# Out:
# x     True
# y     True
# z    False
# Name: c, dtype: bool

# %%
df[df['c']>0] # it displays all the rows of a table where c value >0
# Out:
#       a     b     c     d     e
# x  1.92 -1.44  0.34 -0.85  0.07
# y  1.43  0.29  0.77 -1.81  0.29

# %%
df.drop('a+b',axis=1)# this wont eliminate the 'a+b' coloumn perminantly it doesnt make the change in the actual dataframe
# Out:
#       a     b     c     d     e
# x  1.92 -1.44  0.34 -0.85  0.07
# y  1.43  0.29  0.77 -1.81  0.29
# z -0.68 -0.28 -0.12 -0.82  0.29

# %%
df.drop('a+b',axis=1,inplace=True)
df
# Out:
#       a     b     c     d     e
# x  1.92 -1.44  0.34 -0.85  0.07
# y  1.43  0.29  0.77 -1.81  0.29
# z -0.68 -0.28 -0.12 -0.82  0.29

# %%
df['c']>0   # it displays the
# Out:
# x     True
# y     True
# z    False
# Name: c, dtype: bool

# %%
df[df['c']>0]
# Out:
#       a     b     c     d     e
# x  1.92 -1.44  0.34 -0.85  0.07
# y  1.43  0.29  0.77 -1.81  0.29

# %%
df
# Out:
#       a     b     c     d     e
# x  1.92 -1.44  0.34 -0.85  0.07
# y  1.43  0.29  0.77 -1.81  0.29
# z -0.68 -0.28 -0.12 -0.82  0.29

# %%
df[df['c']>0 & df['b']>0]
df
#it raises error because we are not placing brackets correct syntax is
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
#     304         #  (xint or xbool) and (yint or bool)
# --> 305         result = op(x, y)
#     306     except TypeError:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/roperator.py in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#      55
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/array_ops.py in na_logical_op(x, y, op)
# ...

# %%
df[(df['c']>0) & (df['b']>0)] # it returns the dataframes where the coloumns c and b contains value greater than 0
# Out:
#       a     b     c     d     e
# y  1.43  0.29  0.77 -1.81  0.29

# %% [markdown]
# **creating** **another** **temporary** **dataframe**

# %%
data=np.round(np.random.randn(3,5),2)
cf=pd.DataFrame(data,rows,cols)
print(cf)
# Out:
#       a     b     c     d     e
# x -1.46  0.43 -0.75 -0.60  0.10
# y -1.08 -0.21 -0.63  0.60 -0.14
# z -0.42 -0.85  1.59  1.54 -0.53

# %% [markdown]
# **Reseting** **indexes** **to** **0** '**s** **and** **1** **'** **s**

# %%
cf.reset_index()
# Out:
#   index     a     b     c     d     e
# 0     x -1.46  0.43 -0.75 -0.60  0.10
# 1     y -1.08 -0.21 -0.63  0.60 -0.14
# 2     z -0.42 -0.85  1.59  1.54 -0.53

# %%
cf.set_index('a')
# Out:
#           b     c     d     e
# a
# -1.46  0.43 -0.75 -0.60  0.10
# -1.08 -0.21 -0.63  0.60 -0.14
# -0.42 -0.85  1.59  1.54 -0.53

# %%
cf.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
kf=cf
kf
# Out:
#       a     b     c     d     e
# x -1.46  0.43 -0.75 -0.60  0.10
# y -1.08 -0.21 -0.63  0.60 -0.14
# z -0.42 -0.85  1.59  1.54 -0.53

# %%
kf.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
kf.columns=[1,2,3,4,5]

# %%
kf.columns
# Out:
# Int64Index([1, 2, 3, 4, 5], dtype='int64')
